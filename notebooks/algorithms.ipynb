# %% [markdown]
# # Algorithms

# %% [markdown]
# [Click here to run this chapter on Colab](https://colab.research.google.com/github/AllenDowney/DSIRP/blob/main/notebooks/algorithms.ipynb)

# %% [markdown]
# ## Searching for anagrams
#
# In this notebook we'll implement algorithms for two tasks:
#
# * Testing a pair of words to see if they are anagrams of each other, that is, if you can rearrange the letters in one word to spell the other.
#
# * Searching a list of words for all pairs that are anagrams of each other.
#
# There is a point to these examples, which I will explain at the end.

# %% [markdown]
# **Exercise 1:** Write a function that takes two words and returns `True` if they are anagrams. Test your function with the examples below.

# %%
def is_anagram(word1, word2):
    from collections import Counter
    return Counter(word1) == Counter(word2)

# %%
is_anagram('tachymetric', 'mccarthyite') # True
# Out:
# True

# %%
is_anagram('post', 'top') # False, letter not present
# Out:
# False

# %%
is_anagram('pott', 'top') # False, letter present but not enough copies
# Out:
# False

# %%
is_anagram('top', 'post') # False, letters left over at the end
# Out:
# False

# %%
is_anagram('topss', 'postt') # False
# Out:
# False

# %% [markdown]
# **Exercise 2:** Use `timeit` to see how fast your function is for these examples:

# %%
# %timeit is_anagram('tops', 'spot')
# Out:
# 4.59 µs ± 116 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit is_anagram('tachymetric', 'mccarthyite')
# Out:
# 8.59 µs ± 2.15 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# How can we compare algorithms running on different computers?

# %% [markdown]
# ## Searching for anagram pairs

# %% [markdown]
# **Exercise 3:** Write a function that takes a word list and returns a list of all anagram pairs.

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

# %%
from itertools import product
def all_anagram_pairs(word_list):
    return [(a, b) for a,b in product(word_list, word_list) if is_anagram(a, b)]

# %%
all_anagram_pairs(short_word_list)
# Out:
# [('proudest', 'proudest'),
#  ('proudest', 'sprouted'),
#  ('stop', 'stop'),
#  ('stop', 'pots'),
#  ('stop', 'tops'),
#  ('pots', 'stop'),
#  ('pots', 'pots'),
#  ('pots', 'tops'),
#  ('tops', 'stop'),
#  ('tops', 'pots'),
#  ('tops', 'tops'),
#  ('sprouted', 'proudest'),
#  ('sprouted', 'sprouted')]

# %% [markdown]
# The following cell downloads a file containing a list of English words.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)

download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')
# Out:
# Downloaded american-english

# %% [markdown]
# The following function reads a file and returns a set of words (I used a set because after we convert words to lower case, there are some repeats.)

# %%
def read_words(filename):
    """Read lines from a file and split them into words."""
    res = set()
    for line in open(filename):
        for word in line.split():
            res.add(word.strip().lower())
    return res

# %%
word_list = read_words('american-english')
len(word_list)
# Out:
# 100781

# %% [markdown]
# **Exercise 4:** Loop through the word list and print all words that are anagrams of `stop`.

# %%
[x for x in word_list if is_anagram("stop", x)]
# Out:
# ['pots', 'tops', 'spot', 'post', 'stop', 'opts']

# %% [markdown]
# Now run `all_anagram_pairs` with the full `word_list`:

# %%
pairs = all_anagram_pairs(word_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4032327269.py in <cell line: 0>()
# ----> 1 pairs = all_anagram_pairs(word_list)
#
# /tmp/ipython-input-4284591517.py in all_anagram_pairs(word_list)
#       1 from itertools import product
#       2 def all_anagram_pairs(word_list):
# ----> 3     return [(a, b) for a,b in product(word_list, word_list) if is_anagram(a, b)]
#
# /tmp/ipython-input-2250564555.py in is_anagram(word1, word2)
#       1 def is_anagram(word1, word2):
#       2     from collections import Counter
# ----> 3     return Counter(word1) == Counter(word2)
#
# /usr/lib/python3.12/collections/__init__.py in __eq__(self, other)
#     785     #         (cp > cq) == (sp > sq)
#     786
# --> 787     def __eq__(self, other):
#     788         'True if all counts agree. Missing counts are treated as zero.'
#     789         if not isinstance(other, Counter):
#
# KeyboardInterrupt:

# %% [markdown]
# **Exercise 5:** While that's running, let's estimate how long it's going to take.

# %%
# 8 micros for 1 pair, perform n^2/2 matches we have 1e6 words, 1e12*1e-6, 1e6 seconds, a

# %% [markdown]
# ## A better algorithm
#
# **Exercise 6:** Write a better algorithm! Hint: make a dictionary. How much faster is your algorithm?

# %%
from collections import Counter
def all_anagram_lists(word_list):
    """Finds all anagrams in a list of words.

    word_list: sequence of strings
    """
    known_anagrams = dict()
    for word in word_list:
      canon = "".join(sorted(word))
      if canon in known_anagrams:
        known_anagrams[canon].append(word)
      else:
        known_anagrams[canon] = [word]
    return known_anagrams

# %%
# %time anagram_map = all_anagram_lists(word_list)
# Out:
# CPU times: user 376 ms, sys: 4.96 ms, total: 381 ms
# Wall time: 384 ms

# %%
len(anagram_map)
# Out:
# 93406

# %% [markdown]
# ## Summary
#
# What is the point of the examples in this notebook?
#
# * The different versions of `is_anagram` show that, when inputs are small, it is hard to say which algorithm will be the fastest. It often depends on details of the implementation. Anyway, the differences tend to be small, so it might not matter much in practice.
#
# * The different algorithms we used to search for anagram pairs show that, when inputs are large, we can often tell which algorithm will be fastest. And the difference between a fast algorithm and a slow one can be huge!

# %% [markdown]
# ## Exercises
#
# Before you work on these exercises, you might want to read the Python [Sorting How-To](https://docs.python.org/3/howto/sorting.html). It uses `lambda` to define an anonymous function, which [you can read about here](https://www.w3schools.com/python/python_lambda.asp).
#
# **Exercise 7:**
# Make a dictionary like `anagram_map` that contains only keys that map to a list with more than one element. You can use a `for` loop to make a new dictionary, or a [dictionary comprehension](https://www.freecodecamp.org/news/dictionary-comprehension-in-python-explained-with-examples/).

# %%
{k:v for k,v in anagram_map.items() if len(v) > 1}
# Out:
# {'acdeiiprst': ['pediatrics', 'patricides'],
#  "'befirs": ["brief's", "fiber's"],
#  'ehirssv': ['shrives', 'shivers'],
#  'adegiln': ['aligned', 'dealing', 'leading'],
#  "'oprsst": ["strop's", "sport's"],
#  "'aelnos": ["leona's", "oneal's"],
#  'aeilmsttu': ['stimulate', 'mutilates'],
#  'ainps': ['pains', 'spain'],
#  'eirsttt': ['titters', 'tritest'],
#  'aceilrst': ['recitals', 'articles'],
#  "'beorsst": ["sorbet's", "osbert's", "strobe's"],
#  "'achins": ["chain's", "icahn's", "china's"],
#  "'ehlsstu": ["sleuth's", "hustle's"],
#  'binru': ['rubin', 'bruin'],
#  "'iklos": ["kilo's", "loki's"],
#  'amst': ['mats', 'tams', 'mast'],
#  'beor': ['bore', 'boer', 'ebro', 'robe'],
#  'gmsu': ['gums', 'smug', 'mugs'],
#  'aceilst': ['elastic', 'laciest'],
#  'ddeenp': ['pended', 'depend'],
#  "'eilms": ["lime's", "emil's", "mile's"],
#  'aaeinoprrt': ['reparation', 'praetorian'],
#  'deeimrt': ['merited', 'mitered', 'demerit'],
#  'abeiinrs': ['siberian', 'binaries'],
#  "'aelmnst": ["mantle's", "lament's", "mantel's"],
#  'eehsst': ['sheets', 'theses'],
#  'deimn': ['mined', 'denim'],
#  "'efhlss": ["flesh's", "shelf's"],
#  'egiilnrsv': ['slivering', 'silvering'],
#  "'almors": ["moral's", "molar's"],
#  'aegnrs': ['ranges', 'sanger', 'angers'],
#  'aeinprs': ['persian', 'paniers'],
#  'bdeor': ['bored', 'robed'],
#  'adinrs': ['drains', 'nadirs'],
#  "'achissty": ["chasity's", "scythia's"],
#  'hortw': ['worth', 'wroth', 'throw'],
#  "'aefst": ["feat's", "fate's", "feta's"],
#  "'aorss": ["rosa's", "soar's"],
#  'loos': ['solo', 'oslo'],
#  'adddelw': ['dawdled', 'waddled'],
#  'inst': ['snit', 'tins', 'nits'],
#  "'anrst": ["rant's", "tran's"],
#  "'aamnns": ["annam's", "manna's"],
#  'admnort': ['dormant', 'mordant'],
#  'almor': ['moral', 'molar'],
#  'opst': ['pots', 'tops', 'spot', 'post', 'stop', 'opts'],
#  'oprstu': ['sprout', 'stupor', 'proust'],
#  "'iorst": ["trio's", "riot's", "tiro's"],
#  'amnos': ['mason', 'moans', 'osman'],
#  "'aceehrst": ["hectare's", "teacher's", "cheater's"],
#  'ahmrs': ['harms', 'marsh'],
#  'aest': ['eats', 'sate', 'seat', 'east', 'teas'],
#  'bsu': ['sub', 'bus', 'ubs'],
#  'eenrtu': ['tureen', 'neuter', 'tenure'],
#  'eimrt': ['miter', 'merit', 'remit', 'timer'],
#  'adelst': ['salted', 'deltas', 'lasted', 'slated', 'staled'],
#  "'aorsst": ["astor's", "roast's", "sarto's"],
#  'aelrx': ['laxer', 'relax'],
#  'aben': ['bean', 'bane'],
#  'emoorr': ['romero', 'roomer'],
#  "'eehnorsw": ["erewhon's", "nowhere's"],
#  'diks': ['kids', 'skid', 'disk'],
#  'ademnru': ['manured', 'maunder', 'unarmed'],
#  'loot': ['loot', 'tool'],
#  'ccorsu': ['succor', 'occurs', 'crocus'],
#  'adeppr': ['dapper', 'rapped'],
#  "'aeijnns": ["janine's", "jannie's"],
#  'ceerssu': ['secures', 'rescues'],
#  "'anors": ["arno's", "nora's", "oran's", "roan's", "aron's"],
#  'deflow': ['flowed', 'wolfed', 'fowled'],
#  'aeinprt': ['pertain', 'painter', 'repaint'],
#  'aclry': ['lycra', 'carly'],
#  "'aelmss": ["salem's", "selma's"],
#  'bdeglu': ['bulged', 'bugled'],
#  'belu': ['lube', 'blue'],
#  'agin': ['gina', 'gain', 'agni'],
#  'adehrst': ['threads', 'hardest', 'trashed', 'dearths', 'hatreds'],
#  'eilsv': ['elvis', 'evils', 'veils', 'lives'],
#  'aeilms': ['ismael', 'melisa', 'emails'],
#  'aersst': ['stares', 'asters', 'assert', 'tasers'],
#  'almtuu': ['umlaut', 'mutual'],
#  'ackls': ['calks', 'lacks', 'slack'],
#  'deillt': ['tilled', 'lilted'],
#  "'ailsv": ["vial's", "vila's"],
#  'aenrstv': ['taverns', 'servant'],
#  'behirrt': ['rebirth', 'birther'],
#  'enosst': ['onsets', 'stones'],
#  "'iprssu": ["sirup's", "prius's"],
#  'bdestu': ['debuts', 'busted'],
#  'ailms': ['islam', 'mails'],
#  'adeelrst': ['lestrade', 'treadles'],
#  "'aehrst": ["harte's", "heart's", "earth's", "hater's"],
#  'behlssu': ['blushes', 'bushels'],
#  'aacelnrst': ['lancaster', 'ancestral'],
#  'eegnrs': ['greens', 'genres'],
#  "'inopst": ["point's", "pinto's", "piton's"],
#  'berstu': ['rebuts', 'buster', 'tubers', 'brutes'],
#  'elssty': ['slyest', 'styles'],
#  'aegmnrs': ['mangers', 'germans'],
#  'bdeinr': ['rebind', 'binder', 'inbred'],
#  'degio': ['diego', 'dogie'],
#  'deggilns': ['geldings', 'sledging'],
#  'cekorst': ['rockets', 'restock'],
#  'cdeiinrstt': ['distincter', 'interdicts'],
#  'epst': ['pets', 'step', 'pest'],
#  'is': ['si', 'is'],
#  'aensw': ['weans', 'wanes'],
#  "'orsty": ["tory's", "troy's", "tyro's"],
#  'ceeinorst': ['erections', 'secretion'],
#  "'bnossu": ["bosun's", "bonus's", "bo'suns"],
#  'eegins': ['genies', 'seeing'],
#  "'aclrsy": ["carly's", "lycra's"],
#  'aegmnost': ['megatons', 'montages', 'magnetos'],
#  'aimnst': ['matins', 'mantis'],
#  "'beirst": ["tiber's", "tribe's"],
#  'hort': ['thor', 'roth'],
#  'deforst': ['frosted', 'defrost'],
#  'deinsty': ['density', 'destiny'],
#  'denopr': ['ponder', 'pernod'],
#  'aceeeilmnpt': ['mantelpiece', 'mantlepiece'],
#  'elorr': ['lorre', 'errol'],
#  'anst': ['stan', 'ants', 'tans'],
#  'deinoops': ['poisoned', 'poseidon'],
#  'alms': ['alms', 'slam', 'lams'],
#  'deinw': ['wendi', 'edwin', 'wined', 'widen'],
#  'aginprs': ['rasping', 'parsing', 'sparing', 'parings'],
#  'acert': ['trace', 'cater', 'react', 'crate', 'recta', 'caret'],
#  'aoopprs': ['apropos', 'sapporo'],
#  'egm': ['gem', 'meg'],
#  'abekr': ['break', 'baker', 'brake'],
#  'addeegnr': ['deranged', 'gardened'],
#  'amnors': ['romans', 'manors', 'ransom'],
#  "'ceefprst": ["perfect's", "prefect's"],
#  'aelprtt': ['prattle', 'platter'],
#  "'cdlos": ["cold's", "clod's"],
#  'ddeemrru': ['demurred', 'murdered'],
#  'cehiknst': ['thickens', 'kitchens'],
#  'aabl': ['baal', 'alba'],
#  'ahms': ['hams', 'sham', 'mash'],
#  'aelrsv': ['salver', 'ravels', 'slaver'],
#  'abdeilp': ['piebald', 'bipedal'],
#  "'ist": ["ti's", "it's"],
#  "'agnst": ["gnat's", "tang's"],
#  "'aegopsst": ["postage's", "gestapo's"],
#  'cehos': ['echos', 'chose'],
#  "'abgrs": ["brag's", "grab's", "garb's"],
#  'abekrs': ['breaks', 'brakes', 'bakers'],
#  'ehirs': ['heirs', 'sheri', 'shire', 'hires'],
#  'einsv': ['nevis', 'veins', 'vines'],
#  "'aimmoss": ["mimosa's", "maoism's"],
#  'anor': ['aron', 'nora', 'roan', 'oran', 'arno'],
#  "'beinrstu": ["turbine's", "tribune's"],
#  'esst': ['sets', 'tess'],
#  'aeinstv': ['naivest', 'vainest', 'natives'],
#  'adginrw': ['warding', 'drawing'],
#  'enot': ['note', 'tone', 'eton'],
#  'adefr': ['fared', 'freda'],
#  "'eiorss": ["rosie's", "osier's"],
#  'loop': ['pool', 'loop', 'polo'],
#  "'ioss": ["iso's", "ios's"],
#  'dggginru': ['grudging', 'drugging'],
#  'aabln': ['laban', 'banal'],
#  "'orstu": ["rout's", "tour's"],
#  'gilno': ['lingo', 'login'],
#  'adnors': ['adorns', 'sondra'],
#  'adeor': ['oared', 'adore'],
#  'nrsu': ['urns', 'runs'],
#  'ceelst': ['elects', 'select'],
#  'cehinopt': ['pinochet', 'phonetic'],
#  "'aansssu": ["susana's", "nassau's"],
#  "'aeeijnns": ["jeannie's", "jeanine's"],
#  'aaeehhimprstt': ['amphitheatres', 'amphitheaters'],
#  'ffgiinr': ['griffin', 'riffing'],
#  'aailmns': ['manilas', 'animals', 'malians'],
#  "'eelmrs": ["elmer's", "merle's"],
#  'adeoprrst': ['predators', 'teardrops'],
#  'demos': ['domes', 'modes', 'demos'],
#  'eloorst': ['looters', 'retools'],
#  "'hknsu": ["hunk's", "kuhn's"],
#  'eersst': ['serest', 'steers', 'esters', 'resets'],
#  'aalmr': ['lamar', 'alarm', 'marla'],
#  'eginor': ['ignore', 'region'],
#  'aeimnnost': ['nominates', 'minnesota'],
#  'alst': ['slat', 'lats', 'last', 'salt'],
#  "'anorss": ["arson's", "sonar's"],
#  'cemprstu': ['crumpets', 'spectrum'],
#  'eilnoss': ['insoles', 'lesions', 'lioness'],
#  'aimprt': ['impart', 'armpit'],
#  'aeksw': ['askew', 'wesak', 'wakes'],
#  'aeelps': ['please', 'elapse', 'asleep'],
#  'aabceilrt': ['bacterial', 'calibrate'],
#  'aessss': ['assess', 'sasses'],
#  'belrstu': ['subtler', 'butlers', 'bluster'],
#  'ilstt': ['tilts', 'stilt'],
#  "'berstu": ["tuber's", "brute's"],
#  'ekpsy': ['skype', 'pesky'],
#  'deenrt': ['tender', 'rented'],
#  'aegrs': ['rages', 'gears', 'sager'],
#  'adehss': ['shades', 'dashes'],
#  'cehno': ['cohen', 'enoch'],
#  "'aaikss": ["sakai's", "kasai's"],
#  'deeeirs': ['seedier', 'desiree'],
#  'aeehrtt': ['theatre', 'theater'],
#  "'aprsw": ["wrap's", "warp's"],
#  'aehnsv': ['havens', 'shaven'],
#  'bnrtu': ['brunt', 'burnt'],
#  'acdens': ['dances', 'ascend'],
#  "'bnoss": ["bos'ns", "snob's"],
#  'aehknrs': ['hankers', 'harkens'],
#  "'acrs": ["car's", "arc's", "rca's"],
#  'aegmn': ['megan', 'mange', 'amgen'],
#  'agntu': ['gaunt', 'gatun'],
#  'adegnr': ['gander', 'garden', 'ranged', 'danger'],
#  'aeennrss': ['nearness', 'ensnares'],
#  'aceerrt': ['caterer', 'terrace', 'retrace'],
#  'aglss': ['glass', 'slags'],
#  'cdnoors': ['condors', 'cordons'],
#  "'adnors": ["norad's", "drano's", "ronda's", "radon's"],
#  'aderstv': ['starved', 'adverts'],
#  'nopsstu': ['sunspot', 'unstops'],
#  'agnors': ['groans', 'sarong', 'organs', 'sargon'],
#  'behilprsu': ['publisher', 'republish'],
#  'nosy': ['sony', 'nosy'],
#  'cdeenor': ['encoder', 'encored'],
#  'denps': ['spend', 'pends'],
#  'ceginotv': ['coveting', 'vietcong'],
#  'giiklnn': ['kilning', 'inkling', 'linking'],
#  'amrsw': ['warms', 'swarm'],
#  'enor': ['reno', 'nero'],
#  "'aceilnosst": ["sectional's", "coastline's"],
#  'not': ['not', 'ton'],
#  'eghhist': ['highest', 'eighths', 'heights'],
#  "'aahnssu": ["shauna's", "nashua's"],
#  'deeg': ['edge', 'geed'],
#  "'nstu": ["tun's", "nut's"],
#  "'giorsv": ["virgo's", "vigor's"],
#  'eefgiln': ['fleeing', 'feeling'],
#  "'ehkoorssuw": ["workhouse's", "housework's"],
#  'eiorst': ['tories', 'sortie'],
#  'acelmr': ['marcel', 'calmer'],
#  'cilo': ['loci', 'coil', 'clio'],
#  'bbdeir': ['ribbed', 'bribed'],
#  'eeinrsw': ['newsier', 'wieners'],
#  'oost': ['soot', 'soto'],
#  'eenstv': ['events', 'steven'],
#  "'apsst": ["past's", "spat's"],
#  'abelst': ['stable', 'ablest', 'tables', 'bleats'],
#  'aaimnr': ['marina', 'armani', 'airman', 'marian'],
#  'aeinprst': ['pertains', 'repaints', 'pantries', 'painters'],
#  'eimnnrsttu': ['instrument', 'nutriments'],
#  "'aalsv": ["alva's", "lava's"],
#  'aellorv': ['overall', 'allover'],
#  "'arst": ["tar's", "art's", "rat's"],
#  'aber': ['reba', 'bare', 'bear'],
#  "'acipss": ["aspic's", "spica's"],
#  'egiimmnrs': ['simmering', 'immersing'],
#  "'achmos": ["mocha's", "macho's"],
#  'acdeirss': ['sidecars', 'cressida'],
#  'aeilnort': ['oriental', 'relation'],
#  'ikns': ['skin', 'inks', 'sink'],
#  'ehnorst': ['shorten', 'thrones', 'hornets'],
#  'delos': ['doles', 'soled', 'lodes'],
#  "'aelss": ["elsa's", "lesa's", "seal's", "sale's"],
#  'achno': ['cohan', 'nacho'],
#  'amp': ['pam', 'map', 'amp'],
#  'ceelorst': ['selector', 'electors'],
#  'enrrtuu': ['untruer', 'nurture'],
#  'aeelnsv': ['leavens', 'enslave'],
#  'egilru': ['gluier', 'uglier'],
#  "'inpss": ["spin's", "snip's"],
#  "'abcels": ["cable's", "caleb's"],
#  "'ajnoss": ["jason's", "jonas's", "sonja's"],
#  "'alrsu": ["raul's", "ural's"],
#  'dehnorsu': ['unhorsed', 'enshroud'],
#  'abbbgiln': ['babbling', 'blabbing'],
#  'ceiimorst': ['isometric', 'eroticism'],
#  'aenprt': ['entrap', 'parent'],
#  'ajntu': ['junta', 'jaunt'],
#  'aeeiprsstt': ['tapestries', 'striptease'],
#  'bdeilrsu': ['rebuilds', 'builders'],
#  'adilv': ['vidal', 'advil', 'valid'],
#  'eenss': ['sense', 'essen'],
#  'einrs': ['risen', 'siren', 'reins', 'resin', 'rinse'],
#  'aersttt': ['tartest', 'tatters'],
#  'agginp': ['gaping', 'paging'],
#  'gimnsu': ['musing', 'mingus'],
#  'aeeglst': ['legates', 'eaglets'],
#  'giinrs': ['rising', 'siring'],
#  'egorr': ['regor', 'roger', 'reorg'],
#  'ehlrsstu': ['hustlers', 'ruthless'],
#  'beorst': ['sorbet', 'strobe', 'osbert'],
#  'aefinr': ['fainer', 'efrain'],
#  'epsst': ['steps', 'pests'],
#  "'achmrs": ["charm's", "march's"],
#  'aegmr': ['gamer', 'marge'],
#  'aceiltt': ['tactile', 'lattice'],
#  "'acdilnors": ["alcindor's", "ironclad's"],
#  'ceirrstu': ['recruits', 'crustier'],
#  'ceilrs': ['slicer', 'relics'],
#  'eisv': ['vise', 'ives', 'vies'],
#  'blos': ['lobs', 'slob'],
#  'cehir': ['cheri', 'erich', 'reich'],
#  'adeprs': ['drapes', 'rasped', 'parsed', 'spread', 'spared', 'padres'],
#  'eiilmst': ['limiest', 'elitism'],
#  'eilst': ['islet', 'stile', 'tiles'],
#  'celorsv': ['velcros', 'clovers'],
#  'ceitv': ['evict', 'civet'],
#  'deiopsst': ['deposits', 'topsides'],
#  'acly': ['lacy', 'clay'],
#  'eipqsu': ['piques', 'equips'],
#  "'beors": ["bore's", "ebro's", "robe's", "boer's"],
#  'adeimrr': ['married', 'admirer'],
#  'eeinsv': ['nieves', 'envies'],
#  "'aeeglst": ["eaglet's", "legate's"],
#  'aghns': ['hangs', 'gnash'],
#  'eginrsw': ['wingers', 'swinger'],
#  'aehrs': ['rheas', 'hares', 'share', 'hears', 'shear'],
#  'eflst': ['lefts', 'felts'],
#  'aceorstv': ['overacts', 'overcast'],
#  'eggiln': ['niggle', 'leggin', 'neglig'],
#  'eelnss': ['lenses', 'lessen'],
#  "'eelrsv": ["lever's", "revel's"],
#  'rsttu': ['trust', 'strut'],
#  'deiinoopst': ['positioned', 'deposition'],
#  'acdeeilnrt': ['interlaced', 'credential'],
#  'deeefr': ['reefed', 'feeder'],
#  "'ceorsst": ["cortes's", "corset's", "sector's", "escort's"],
#  'adfhlnsu': ['handfuls', 'handsful'],
#  'aelpt': ['pleat', 'plate', 'leapt', 'patel', 'petal'],
#  'adeeinprt': ['pertained', 'repainted'],
#  'eekp': ['keep', 'peek'],
#  'acnst': ['scant', 'cants'],
#  "'aeelrss": ["resale's", "sealer's"],
#  'aenv': ['neva', 'evan', 'nave', 'vane'],
#  'efilr': ['flier', 'rifle', 'lifer'],
#  "'aagmms": ["magma's", "gamma's"],
#  'films': ['films', 'milfs'],
#  'aacllsuy': ['casually', 'causally'],
#  'hostu': ['thous', 'shout', 'south'],
#  'belmrstu': ['stumbler', 'tumbrels', 'tumblers'],
#  'ceeinrsu': ['insecure', 'sinecure'],
#  'ghinoop': ['poohing', 'hooping'],
#  'aalss': ['lassa', 'salsa', 'salas'],
#  "'densu": ["nude's", "dune's"],
#  "'emnoors": ["monroe's", "moreno's"],
#  "'alors": ["lora's", "oral's"],
#  'eoprstu': ['proteus', 'posture', 'troupes'],
#  'aaclrs': ['rascal', 'scalar'],
#  'aeeiln': ['elaine', 'aileen'],
#  'aadeipprs': ['disappear', 'appraised'],
#  'eegiknn': ['kneeing', 'keening'],
#  "'dinos": ["odin's", "dino's", "dion's"],
#  'aelnors': ['loaners', 'salerno', 'orleans'],
#  "'aeilrss": ["serial's", "israel's"],
#  "'acders": ["cadre's", "cedar's"],
#  'ggilnoss': ['glossing', 'goslings'],
#  'adel': ['lead', 'dale', 'deal', 'leda', 'lade'],
#  'dggiiln': ['gilding', 'gliding'],
#  'eops': ['pose', 'peso'],
#  'deru': ['rude', 'rued'],
#  'deirw': ['wired', 'weird', 'wider'],
#  "'''cefloss": ["fo'c's'les", "fo'c'sle's"],
#  'ips': ['sip', 'pis'],
#  "'aeksst": ["stake's", "skate's", "steak's", "keats's"],
#  "'enrst": ["tern's", "rent's"],
#  'deiklns': ['slinked', 'kindles'],
#  "'dost": ["tod's", "dot's"],
#  'ehiknrst': ['thinkers', 'rethinks'],
#  'dfnou': ['fondu', 'found'],
#  'acillost': ['callisto', 'castillo'],
#  'aekl': ['lake', 'leak', 'kale'],
#  'ehikrs': ['shriek', 'shrike', 'hikers'],
#  'adeerr': ['reread', 'dearer', 'reared', 'reader'],
#  'adennoy': ['anodyne', 'annoyed'],
#  'mnoo': ['mono', 'moon'],
#  "'belorsst": ["bolster's", "lobster's"],
#  'eeeinnrst': ['internees', 'ernestine'],
#  'histw': ['whist', 'whits'],
#  'iimnprst': ['imprints', 'misprint'],
#  "'fnostu": ["futon's", "fount's"],
#  'aeiprr': ['rapier', 'repair'],
#  'abgrs': ['grabs', 'brags', 'garbs'],
#  'airsst': ['stairs', 'sitars'],
#  'acghinnst': ['snatching', 'stanching'],
#  'aahinst': ['tanisha', 'ashanti'],
#  'ehiks': ['sheik', 'hikes'],
#  "'aalrs": ["aral's", "lara's", "alar's"],
#  'dgino': ['doing', 'dingo'],
#  'enop': ['pone', 'open', 'nope', 'peon'],
#  "'aghss": ["shag's", "gash's"],
#  'abder': ['debar', 'debra', 'bread', 'beard', 'bared'],
#  'acegors': ['cargoes', 'corsage'],
#  'cceeghiknr': ['checkering', 'rechecking'],
#  'aeilmnr': ['mineral', 'manlier'],
#  'alnost': ['alston', 'talons', 'salton'],
#  'aeerrsw': ['swearer', 'wearers'],
#  'abcs': ['cabs', 'scab'],
#  'aknrs': ['ranks', 'narks'],
#  'adest': ['dates', 'stead', 'sated'],
#  'aeklnr': ['rankle', 'lanker'],
#  'eglorv': ['glover', 'grovel'],
#  'giprs': ['prigs', 'sprig', 'grips'],
#  'dhimoru': ['humidor', 'rhodium'],
#  "'delosy": ["doyle's", "yodel's"],
#  'cimnors': ['crimson', 'microns'],
#  "'acehoprs": ["poacher's", "pechora's"],
#  'dim': ['dim', 'mid'],
#  'cdeeiorrsv': ['discoverer', 'rediscover'],
#  'alsw': ['awls', 'laws', 'slaw'],
#  'adeginprv': ['depraving', 'pervading'],
#  'amory': ['moray', 'mayor'],
#  'aeeirstt': ['treaties', 'treatise', 'teariest', 'iterates'],
#  'eimr': ['mire', 'rime', 'emir', 'meir'],
#  "'eelrs": ["reel's", "leer's"],
#  'eelrsstt': ['trestles', 'settlers'],
#  'efilst': ['itself', 'filets', 'stifle', 'fliest'],
#  "'abginsu": ["ubangi's", "bangui's"],
#  'ehs': ['hes', 'she'],
#  "'behirrst": ["rebirth's", "birther's"],
#  'dgiinss': ['dissing', 'sidings'],
#  'adeiprt': ['pirated', 'partied'],
#  'aahmrs': ['marsha', 'ashram'],
#  'acehnrst': ['chanters', 'stancher'],
#  "'aelnrst": ["antler's", "rental's"],
#  'cenor': ['creon', 'crone'],
#  'deirr': ['direr', 'drier', 'rider'],
#  'delo': ['dole', 'lode'],
#  'been': ['been', 'eben'],
#  "'beehsst": ["thebes's", "behest's"],
#  'ahst': ['hats', 'shat'],
#  'apr': ['apr', 'rap', 'par'],
#  'deiks': ['skied', 'dikes'],
#  "'aelsv": ["veal's", "elva's", "vale's", "vela's"],
#  "'aeirss": ["aries's", "aires's", "raise's"],
#  'aepr': ['pear', 'pare', 'reap', 'rape', 'earp'],
#  'addelw': ['waddle', 'dawdle'],
#  'acenrt': ['cretan', 'recant', 'nectar', 'canter', 'trance'],
#  'aginpr': ['paring', 'raping'],
#  'ainsst': ['stains', 'saints'],
#  'aemn': ['mane', 'amen', 'name', 'mean'],
#  'bbgimno': ['mobbing', 'bombing'],
#  'acdel': ['laced', 'decal'],
#  'enrrtu': ['return', 'turner'],
#  'aeln': ['lena', 'neal', 'lane', 'lean'],
#  'eirt': ['tire', 'rite', 'tier', 'teri'],
#  'clot': ['colt', 'clot'],
#  'adddeemn': ['demanded', 'maddened'],
#  'aelry': ['early', 'layer', 'leary', 'relay'],
#  'deorstu': ['detours', 'dourest'],
#  'eessx': ['sexes', 'essex'],
#  'aimms': ['maims', 'imams'],
#  'aeeilntttvy': ['attentively', 'tentatively'],
#  'deelprsu': ['preludes', 'repulsed'],
#  'derstu': ['duster', 'rudest', 'rusted'],
#  "'aacclrsu": ["accrual's", "caracul's"],
#  'eoprsstt': ['spotters', 'protests'],
#  'ajnstu': ['jaunts', 'juntas'],
#  'eeenorsv': ['veronese', 'overseen'],
#  'hoos': ['soho', 'shoo'],
#  'eilnno': ['lonnie', 'online'],
#  'aelm': ['male', 'lame', 'meal', 'elam', 'elma'],
#  'aaimnrt': ['martian', 'martina'],
#  'adeiinoprtt': ['trepidation', 'partitioned'],
#  "'deist": ["diet's", "tide's", "edit's"],
#  'eersstt': ['testers', 'setters', 'tersest', 'streets'],
#  'deeegnr': ['greened', 'reneged'],
#  'agst': ['tags', 'stag'],
#  'hosstu': ['souths', 'shouts'],
#  "'aellrsu": ["allure's", "laurel's"],
#  'aeksst': ['skates', 'stakes', 'steaks'],
#  'eimrss': ['remiss', 'misers'],
#  'denorst': ['snorted', 'rodents'],
#  "'aceelrst": ["treacle's", "electra's"],
#  'aeprssst': ['sparsest', 'trespass'],
#  "'aegnos": ["onega's", "genoa's"],
#  "'amrs": ["ram's", "mar's", "arm's"],
#  "'bdeist": ["bidet's", "debit's"],
#  'aeilrst': ['retails', 'saltier', 'realist'],
#  'aehlss': ['hassle', 'lashes'],
#  'aelsst': ['tassel', 'steals', 'slates', 'stales'],
#  'aegnrrs': ['garners', 'rangers'],
#  'cdeeirstt': ['trisected', 'directest'],
#  'eorstv': ['voters', 'strove'],
#  'defiiln': ['infield', 'infidel'],
#  'defgiiins': ['dignifies', 'signified'],
#  'eghiilnrs': ['relishing', 'hirelings'],
#  'dehrs': ['herds', 'sherd', 'shred'],
#  'aacdeemrt': ['demarcate', 'macerated'],
#  'aceimnr': ['carmine', 'crimean'],
#  "'inprstu": ["turpin's", "turnip's"],
#  'aceprss': ['parsecs', 'scrapes'],
#  'acdep': ['caped', 'paced'],
#  'achin': ['china', 'chain', 'icahn'],
#  'adenrs': ['andres', 'sander', 'snared'],
#  "'eoqstu": ["toque's", "quote's"],
#  'elosu': ['louse', 'seoul'],
#  'lmpsu': ['lumps', 'plums', 'slump'],
#  'degilor': ['godlier', 'gloried'],
#  "'eilosv": ["voile's", "olive's"],
#  'abdelmr': ['marbled', 'rambled'],
#  'iorst': ['trios', 'torsi', 'tiros', 'riots'],
#  'adegln': ['angled', 'dangle', 'glenda'],
#  "'eillnst": ["lintel's", "lentil's"],
#  'eisstx': ['exists', 'sexist'],
#  "'bennost": ["benton's", "bonnet's"],
#  'acgillnor': ['carolling', 'collaring'],
#  'alpsy': ['palsy', 'plays', 'splay'],
#  'aginnttu': ['attuning', 'taunting'],
#  'aehlsw': ['whales', 'wheals'],
#  'dstuy': ['study', 'dusty'],
#  'abilopr': ['parboil', 'bipolar'],
#  'aelntt': ['latent', 'talent'],
#  'deiilmt': ['limited', 'delimit'],
#  'aegrz': ['gazer', 'graze'],
#  'kloootu': ['outlook', 'lookout'],
#  'ac': ['ac', 'ca'],
#  'ghinors': ['shoring', 'horsing'],
#  "'bdoors": ["dobro's", "brood's"],
#  'aabdor': ['abroad', 'aboard', 'baroda'],
#  'celu': ['clue', 'luce'],
#  'adghins': ['shading', 'dashing'],
#  'acely': ['lacey', 'alyce'],
#  'abeillry': ['blearily', 'reliably'],
#  'ddegir': ['ridged', 'girded'],
#  "'agimnrs": ["margin's", "ingram's"],
#  'ceefhist': ['fetiches', 'chiefest'],
#  'hnstu': ['shunt', 'hunts'],
#  'aelnssu': ['unseals', 'sensual'],
#  "'eoprsst": ["poster's", "presto's"],
#  "'aacinorst": ["raincoat's", "croatian's"],
#  'deist': ['edits', 'sited', 'tides', 'diets'],
#  "'acllost": ["lolcat's", "tlaloc's"],
#  'eprssu': ['supers', 'purses'],
#  'deopt': ['opted', 'depot'],
#  'aemssu': ['amuses', 'assume'],
#  'efgor': ['gofer', 'forge'],
#  'abegl': ['bagel', 'gable'],
#  'eiknrtt': ['knitter', 'trinket'],
#  "'belmrstu": ["tumbler's", "tumbrel's"],
#  'aginrt': ['rating', 'taring'],
#  "'aehst": ["hate's", "thea's", "heat's"],
#  'acimr': ['marci', 'micra'],
#  'abls': ['slab', 'labs', 'albs'],
#  'acmsu': ['camus', 'sumac'],
#  "'aesstw": ["sweat's", "waste's"],
#  'apsy': ['pays', 'spay', 'yaps'],
#  'deens': ['needs', 'edens', 'dense'],
#  'aadmrs': ['dramas', 'madras'],
#  'aeilnpss': ['painless', 'spaniels'],
#  'elmno': ['lemon', 'melon'],
#  'deeinpr': ['dnieper', 'ripened'],
#  'acnno': ['canon', 'conan'],
#  'defmors': ['deforms', 'serfdom'],
#  'ceortv': ['vector', 'covert'],
#  'aehlst': ['halest', 'lathes', 'thales'],
#  'cehist': ['ethics', 'itches'],
#  'esu': ['use', 'sue'],
#  'einv': ['vine', 'vein'],
#  'adeennrs': ['ensnared', 'andersen'],
#  "'egiorst": ["goitre's", "goiter's"],
#  'eew': ['wee', 'ewe'],
#  'aelmnst': ['mantels', 'laments', 'mantles'],
#  "'acehilms": ["michael's", "micheal's"],
#  'elops': ['lopes', 'poles', 'slope'],
#  'adeegnr': ['grandee', 'derange', 'angered', 'grenade', 'enraged'],
#  'abeelstt': ['testable', 'settable'],
#  "'aijnns": ["ninja's", "jinan's"],
#  "'aelms": ["meal's", "male's", "elma's", "elam's", "lame's"],
#  'eeprs': ['speer', 'spree', 'peers'],
#  'deilnstu': ['unlisted', 'insulted'],
#  'aeprs': ['spear', 'pares', 'reaps', 'parse', 'pears', 'spare', 'rapes'],
#  "'beffrsu": ["buffer's", "rebuff's"],
#  'dnosy': ['synod', 'dyson'],
#  "'almsu": ["alum's", "maul's"],
#  'adnsw': ['wands', 'dawns'],
#  'aeiilnst': ['litanies', 'taliesin'],
#  'ddeegin': ['deeding', 'deigned'],
#  'anoprst': ['tarpons', 'patrons'],
#  "'airs": ["air's", "ira's"],
#  'adeeenrtv': ['enervated', 'venerated'],
#  'aelpr': ['pearl', 'paler'],
#  'beeioqssu': ['essequibo', 'obsequies'],
#  'oott': ['otto', 'toot', 'toto'],
#  'ehinrs': ['shrine', 'shiner'],
#  'deilmnss': ['mildness', 'mindless'],
#  'abdeginr': ['breading', 'bearding'],
#  'enost': ['stone', 'seton', 'onset', 'notes', 'tones'],
#  'ceinost': ['section', 'notices'],
#  'aehmrs': ['harems', 'masher'],
#  "'moors": ["moor's", "room's", "moro's"],
#  'abdees': ['seabed', 'debase'],
#  'eoprt': ['trope', 'perot'],
#  'aenstu': ['unseat', 'austen'],
#  'aeills': ['sallie', 'allies'],
#  'abbdels': ['dabbles', 'slabbed'],
#  'adeeimnoprst': ['predominates', 'impersonated'],
#  'eilt': ['tile', 'lite'],
#  "'aefinns": ["fannie's", "fenian's"],
#  "'aeills": ["allie's", "leila's", "lelia's"],
#  "'aeehrstt": ["theater's", "theatre's"],
#  'ehisst': ['thesis', 'heists'],
#  'einooprs': ['snoopier', 'poisoner'],
#  'dioprt': ['torpid', 'tripod'],
#  'eorsu': ['rouse', 'euros'],
#  "'innosu": ["inonu's", "union's"],
#  'aeeinrt': ['trainee', 'retinae'],
#  'aeilnr': ['arline', 'linear'],
#  'einoprst': ['proteins', 'pointers'],
#  'certu': ['truce', 'cruet', 'cuter'],
#  "'aegimns": ["enigma's", "gamine's"],
#  "'afrst": ["raft's", "fart's", "frat's"],
#  'eehnorw': ['erewhon', 'whereon', 'nowhere'],
#  "'aairst": ["atari's", "tiara's", "atria's"],
#  'acdeenrt': ['decanter', 'cantered', 'recanted'],
#  'aceens': ['encase', 'seneca'],
#  "'acdeiimnost": ["decimation's", "medication's"],
#  "'abeirss": ["serbia's", "rabies's"],
#  'aelmv': ['velma', 'melva'],
#  'ahsw': ['wash', 'haws', 'shaw'],
#  "'aelmsv": ["melva's", "velma's"],
#  'acort': ['actor', 'croat'],
#  'adeesv': ['evades', 'deaves'],
#  'eel': ['lee', 'eel'],
#  'cinos': ['icons', 'sonic', 'coins', 'scion'],
#  'almu': ['alum', 'maul'],
#  'acitt': ['tacit', 'attic'],
#  'celru': ['ulcer', 'lucre', 'cruel'],
#  'eorrst': ['resort', 'torres', 'roster', 'sorter'],
#  'aderstw': ['strawed', 'steward'],
#  'aps': ['asp', 'pas', 'sap', 'spa'],
#  'eisstu': ['suites', 'tissue'],
#  'acdekr': ['arcked', 'racked'],
#  'acdegiimnt': ['decimating', 'medicating'],
#  'hiirst': ['tishri', 'irtish'],
#  'aeoprssv': ['passover', 'overpass'],
#  'aimost': ['taoism', 'maoist'],
#  'abnru': ['urban', 'unbar'],
#  "'agils": ["gila's", "gail's"],
#  'eellrt': ['retell', 'teller'],
#  'eeehstt': ['teethes', 'esthete'],
#  'aenprst': ['entraps', 'napster', 'pastern', 'parents'],
#  'aailsv': ['avails', 'saliva'],
#  'einprrst': ['printers', 'sprinter', 'reprints'],
#  'aeekortv': ['takeover', 'overtake'],
#  "'deenrsv": ["vender's", "denver's"],
#  "'imrs": ["mir's", "rim's"],
#  'deentt': ['tented', 'netted'],
#  'aceprst': ['carpets', 'spectra'],
#  'essu': ['suse', 'sues', 'uses'],
#  "'alsw": ["law's", "awl's"],
#  "'aelnps": ["panel's", "nepal's", "plane's"],
#  'aejn': ['jane', 'jean'],
#  "'pssu": ["ups's", "sup's", "pus's"],
#  'deeirrw': ['rewired', 'weirder'],
#  'bdenorsu': ['bounders', 'rebounds', 'suborned'],
#  'delostu': ['loudest', 'tousled'],
#  'adelnr': ['lenard', 'lander'],
#  'adeelrt': ['treadle', 'related', 'alerted', 'altered'],
#  'eenprsst': ['pertness', 'serpents', 'presents'],
#  'iprst': ['trips', 'strip'],
#  'apt': ['tap', 'pat', 'apt'],
#  "'ceorssu": ["course's", "source's", "crusoe's"],
#  'aeiinnstu': ['annuities', 'insinuate'],
#  'adepst': ['adepts', 'pasted'],
#  'gin': ['ing', 'gin'],
#  'knpsu': ['punks', 'spunk'],
#  "'aersstw": ["waters's", "waster's"],
#  'aacnpst': ['capstan', 'catnaps'],
#  'deerstw': ['strewed', 'wrested'],
#  'aeeegrst': ['steerage', 'eagerest'],
#  'dmoos': ['sodom', 'moods', 'dooms'],
#  'ehinrss': ['shrines', 'shiners'],
#  'aswy': ['yaws', 'sway', 'ways'],
#  "'cceilrs": ["cleric's", "circle's"],
#  'abesst': ['basest', 'beasts', 'bastes'],
#  "'egnors": ["goren's", "goner's", "negro's"],
#  'anp': ['pan', 'nap'],
#  'adeggr': ['dagger', 'ragged'],
#  'abesu': ['beaus', 'abuse'],
#  'acceips': ['icecaps', 'ipecacs'],
#  'aenrst': ['sterna', 'astern'],
#  'abdeirss': ['sidebars', 'seabirds'],
#  "'eissv": ["ives's", "vise's"],
#  'aeprt': ['prate', 'petra', 'taper', 'apter'],
#  'bddeeit': ['betided', 'debited'],
#  'elrstu': ['rustle', 'lustre', 'result', 'ulster', 'luster'],
#  'bdeist': ['debits', 'bidets'],
#  'aimmoss': ['mimosas', 'maoisms'],
#  'aelnp': ['plane', 'penal', 'nepal', 'panel'],
#  'ckops': ['pocks', 'spock'],
#  'acdnor': ['dacron', 'candor', 'conrad'],
#  'aglno': ['logan', 'along', 'golan', 'anglo'],
#  "'aswy": ["way's", "yaw's"],
#  "'ccorssu": ["crocus's", "succor's"],
#  'aknor': ['akron', 'koran'],
#  'ailrst': ['trials', 'trails'],
#  "'egors": ["gore's", "ogre's", "roeg's"],
#  'eflu': ['flue', 'fuel'],
#  'adenpp': ['napped', 'append'],
#  "'eenprsss": ["spenser's", "serpens's"],
#  'aeilnrt': ['latiner', 'retinal', 'reliant', 'latrine'],
#  'apsty': ['pasty', 'patsy'],
#  'hiiknps': ['kinship', 'pinkish'],
#  "'ceiklnrs": ["clinker's", "crinkle's"],
#  "'abelstt": ["battle's", "tablet's"],
#  'adepss': ['passed', 'spades'],
#  "'aims": ["mai's", "mia's", "aim's"],
#  'eirs': ['reis', 'eris', 'sire', 'rise'],
#  "'ainrs": ["nair's", "rain's", "iran's"],
#  'chin': ['inch', 'chin'],
#  'eery': ['eyre', 'eery'],
#  'ainstu': ['unitas', 'austin'],
#  'egnor': ['goner', 'goren', 'negro'],
#  'bbbdelo': ['bobbled', 'blobbed'],
#  'alop': ['opal', 'alpo'],
#  'alnot': ['talon', 'alton', 'tonal'],
#  "'acilnsu": ["lucian's", "alcuin's"],
#  'oorst': ['roost', 'torso', 'roots'],
#  'answ': ['swan', 'sawn'],
#  "'hosst": ["shot's", "host's"],
#  'eefl': ['flee', 'feel'],
#  'aggin': ['aging', 'nigga'],
#  'aabhistt': ['baathist', 'habitats'],
#  "'efilrst": ["trifle's", "filter's"],
#  "'ainsst": ["saint's", "satin's", "stain's"],
#  "'aklrs": ["karl's", "lark's"],
#  'adeehrs': ['headers', 'sheared', 'adheres'],
#  'eilm': ['emil', 'lime', 'mile'],
#  'elnors': ['loners', 'enrols'],
#  'denrs': ['nerds', 'rends'],
#  "'dmoos": ["mood's", "doom's", "odom's"],
#  'hnort': ['north', 'thorn'],
#  "'hrstu": ["ruth's", "hurt's"],
#  "'eekps": ["keep's", "peek's"],
#  'aefsst': ['safest', 'feasts'],
#  'emrsu': ['remus', 'serum'],
#  'einps': ['snipe', 'penis', 'spine', 'pines'],
#  'abderu': ['earbud', 'dauber'],
#  "'aers": ["rae's", "era's", "ear's", "are's"],
#  'aimr': ['irma', 'mira', 'mari', 'amir'],
#  'agilnsv': ['salving', 'slaving'],
#  'for': ['fro', 'for'],
#  'aaeiilnorstt': ['aristotelian', 'retaliations'],
#  'adeeimstt': ['meditates', 'estimated'],
#  'cdeor': ['decor', 'credo', 'cored'],
#  'aeggilnr': ['ganglier', 'regaling'],
#  'aehprs': ['sharpe', 'phrase', 'seraph', 'sherpa'],
#  'einsst': ['steins', 'insets'],
#  'aaeemnt': ['enemata', 'emanate', 'manatee'],
#  'ceehiknrt': ['thickener', 'kitchener'],
#  'aeiprst': ['parties', 'pirates', 'pastier', 'traipse'],
#  'ddeiltu': ['luddite', 'diluted'],
#  'ckmos': ['smock', 'mocks'],
#  'aeijm': ['jaime', 'jamie', 'mejia'],
#  'orstu': ['routs', 'torus', 'tours'],
#  "'enost": ["eton's", "tone's", "note's"],
#  'oort': ['oort', 'root'],
#  'delow': ['lowed', 'dowel'],
#  'agot': ['goat', 'toga'],
#  'abst': ['stab', 'bats', 'tabs', 'bast'],
#  'ins': ['sin', 'ins'],
#  'int': ['tin', 'nit'],
#  'eeilrv': ['eviler', 'relive', 'revile'],
#  "'aeemnssttt": ["testament's", "statement's"],
#  'aensttu': ['attunes', 'tetanus'],
#  'deefr': ['defer', 'freed'],
#  'aakos': ['asoka', 'osaka'],
#  'acegimnrt': ['cremating', 'centigram'],
#  'ags': ['sag', 'gas'],
#  "'bgrsu": ["grub's", "burg's"],
#  'adekst': ['tasked', 'skated', 'staked'],
#  "'abenrs": ["abner's", "arneb's"],
#  "'dggilnos": ["lodging's", "golding's"],
#  "'eiprsst": ["stripe's", "sprite's", "priest's"],
#  "'opst": ["pot's", "top's"],
#  "'celmnoss": ["clemons's", "clemson's"],
#  'dggilno': ['lodging', 'golding'],
#  'adeelr': ['dealer', 'leader'],
#  'deintu': ['untied', 'united'],
#  'ceiklnrs': ['clinkers', 'crinkles'],
#  'aefgiln': ['finagle', 'leafing'],
#  'ehilost': ['hostile', 'holiest'],
#  'filt': ['lift', 'flit'],
#  'cenortu': ['recount', 'trounce', 'counter'],
#  'eimprstu': ['stumpier', 'impurest'],
#  'acdeprs': ['scraped', 'redcaps'],
#  'aefhilsst': ['flashiest', 'faithless'],
#  'aabrs': ['basra', 'arabs'],
#  "'adegilns": ["leading's", "dealing's"],
#  "'abeeknnrs": ["bernanke's", "banneker's"],
#  'addels': ['addles', 'saddle'],
#  'oprst': ['ports', 'sport', 'strop'],
#  "'adeiss": ["sadie's", "aside's"],
#  'acehst': ['scheat', 'sachet', 'cheats', 'chaste'],
#  'cdelru': ['curdle', 'curled'],
#  'eikrss': ['skiers', 'kisser'],
#  "'acsst": ["acts's", "scat's", "cast's"],
#  'aelpst': ['palest', 'pleats', 'petals', 'staple', 'plates', 'pastel'],
#  'deeinv': ['envied', 'endive', 'veined'],
#  "'einpss": ["penis's", "spine's", "snipe's"],
#  'eeginrst': ['integers', 'steering', 'gentries'],
#  'ersst': ['tress', 'rests'],
#  'agiilnost': ['isolating', 'intaglios'],
#  "'aersw": ["wear's", "ware's"],
#  "'adeilns": ["daniel's", "denial's"],
#  'giimnr': ['riming', 'miring'],
#  'abbeist': ['tabbies', 'babiest'],
#  'adeinst': ['detains', 'stained', 'instead'],
#  "'eilnns": ["linen's", "lenin's"],
#  "'acels": ["alec's", "lace's"],
#  'bbginos': ['gibbons', 'sobbing'],
#  'ahopst': ['potash', 'pathos'],
#  'acgiinnotu': ['cautioning', 'auctioning'],
#  'ahmnsu': ['hamsun', 'humans'],
#  'cginost': ['costing', 'gnostic'],
#  'alov': ['olav', 'oval'],
#  "'aenrrsw": ["warren's", "warner's"],
#  'eimt': ['emit', 'item', 'time', 'mite'],
#  'aeilv': ['elvia', 'alive'],
#  "'bdosy": ["boyd's", "body's"],
#  'ccdeenort': ['concreted', 'concerted'],
#  "'enorsst": ["sterno's", "stoner's", "nestor's"],
#  'aenprstt': ['transept', 'patterns'],
#  'aceeirtv': ['creative', 'reactive'],
#  'adderw': ['edward', 'warded'],
#  'alsuu': ['usual', 'luaus'],
#  "'effis": ["fife's", "fief's"],
#  'aklr': ['lark', 'karl'],
#  'aekls': ['leaks', 'slake', 'lakes'],
#  'beorsw': ['bowers', 'browse'],
#  'eimnstu': ['minuets', 'minutes'],
#  'emo': ['emo', 'moe'],
#  'aalmnu': ['manual', 'alumna'],
#  'admnosy': ['dynamos', 'mondays'],
#  'hnsu': ['huns', 'shun'],
#  'acdert': ['traced', 'carted', 'crated'],
#  'eotv': ['vote', 'veto'],
#  "'abls": ["alb's", "lab's"],
#  "'acceinos": ["cocaine's", "oceanic's"],
#  'ipst': ['tips', 'spit', 'pits'],
#  "'ellsy": ["yell's", "lyle's"],
#  'eiln': ['neil', 'lien', 'nile', 'line'],
#  'aeglns': ['angles', 'gleans', 'angels'],
#  'agimnr': ['margin', 'ingram', 'arming'],
#  'aeghnopst': ['heptagons', 'pathogens'],
#  'ailru': ['luria', 'lauri'],
#  'abde': ['bead', 'abed', 'bade'],
#  'einort': ['orient', 'tonier'],
#  "'aalmrs": ["lamar's", "marla's", "alarm's"],
#  'abenry': ['nearby', 'barney'],
#  'bdemoor': ['boredom', 'bedroom'],
#  'aginpv': ['vaping', 'paving'],
#  'einst': ['nites', 'inset', 'stein', 'tines', 'stine'],
#  'cefors': ['forces', 'fresco'],
#  'aeghrt': ['gareth', 'gather'],
#  "'cosst": ["scot's", "cost's"],
#  'ehost': ['ethos', 'those'],
#  'desu': ['duse', 'dues', 'sued', 'used'],
#  'eilrs': ['riles', 'slier'],
#  "'emoorrs": ["roomer's", "romero's"],
#  'abdeis': ['biased', 'abides'],
#  'eiilmss': ['similes', 'missile'],
#  'elorw': ['rowel', 'lower'],
#  'acellr': ['caller', 'recall', 'cellar'],
#  'eglru': ['luger', 'gruel'],
#  'aaceirv': ['caviare', 'avarice'],
#  'adeknr': ['kendra', 'darken', 'danker', 'ranked', 'narked'],
#  'cot': ['cot', 'oct'],
#  'aclrsw': ['scrawl', 'crawls'],
#  'eersv': ['sever', 'serve', 'veers', 'verse'],
#  'eimnoprstu': ['importunes', 'resumption'],
#  "'efrrsy": ["ferry's", "fryer's"],
#  "'blosw": ["blow's", "bowl's"],
#  'adegilnp': ['pedaling', 'pleading'],
#  'eilnsv': ['snivel', 'livens'],
#  "'abbsy": ["abby's", "baby's"],
#  'fnostu': ['futons', 'founts'],
#  'dehimnos': ['sondheim', 'hedonism'],
#  'eiqtu': ['quiet', 'quite'],
#  'ahmnu': ['human', 'nahum'],
#  'lstu': ['lust', 'slut'],
#  'einr': ['erin', 'rein'],
#  'eemorst': ['meteors', 'remotes'],
#  'aamnn': ['manna', 'annam'],
#  "'eekls": ["keel's", "leek's", "klee's"],
#  'aaelnprt': ['prenatal', 'paternal', 'parental'],
#  "'acehrss": ["chaser's", "search's"],
#  'ghirt': ['girth', 'right'],
#  "'cehirs": ["cheri's", "reich's", "erich's"],
#  'beegrr': ['berger', 'gerber'],
#  'bbcelor': ['cobbler', 'clobber'],
#  "'ehikst": ["keith's", "kieth's"],
#  'ceorst': ['corset', 'cortes', 'escort', 'sector'],
#  'bdeilrst': ['bristled', 'driblets'],
#  'ersstu': ['russet', 'surest'],
#  "'aeimnors": ["romaine's", "moraine's"],
#  'ceersu': ['rescue', 'secure'],
#  'eloort': ['retool', 'looter'],
#  'deooprst': ['torpedos', 'doorstep'],
#  'adeerrs': ['readers', 'rereads'],
#  'eivw': ['wive', 'view'],
#  "'bdemoors": ["bedroom's", "boredom's"],
#  'ceiinnopst': ['inceptions', 'inspection'],
#  'air': ['air', 'ira'],
#  'erssstu': ['russets', 'trusses'],
#  'bgos': ['gobs', 'bogs'],
#  'ceorstv': ['coverts', 'vectors'],
#  'ejst': ['jets', 'jest'],
#  'aehl': ['hale', 'leah', 'heal'],
#  'aeinrrt': ['trainer', 'terrain', 'retrain'],
#  'cdinostu': ['conduits', 'discount'],
#  'adefry': ['defray', 'frayed'],
#  'denos': ['nosed', 'nodes'],
#  'aelmprt': ['templar', 'trample'],
#  'aelst': ['stael',
#   'stale',
#   'tales',
#   'slate',
#   'tesla',
#   'teals',
#   'steal',
#   'least'],
#  'abeert': ['berate', 'rebate', 'beater'],
#  'arsty': ['artsy', 'satyr', 'stray', 'trays'],
#  'rsstu': ['rusts', 'truss'],
#  "'amrst": ["tram's", "mart's"],
#  "'eelrsstt": ["trestle's", "settler's"],
#  'bdelloors': ['doorbells', 'bordellos'],
#  'dehor': ['rhode', 'herod', 'horde'],
#  'als': ['sal', 'las'],
#  'ccehios': ['cochise', 'choices'],
#  'ehistt': ['theist', 'tithes'],
#  'degilrs': ['girdles', 'gliders'],
#  "'aeelstz": ["teazle's", "teazel's"],
#  'eilppst': ['stipple', 'tipples'],
#  'egt': ['get', 'gte'],
#  'einrstv': ['inverts', 'striven'],
#  'aehr': ['rhea', 'hare', 'hera', 'hear'],
#  "'aaceimnrs": ["cinerama's", "american's"],
#  "'ehikrss": ["shriek's", "shrike's"],
#  'eirsst': ['sister', 'resist'],
#  'actt': ['tact', 'catt'],
#  'einorst': ['orients', 'stonier'],
#  'adeelps': ['pleased', 'elapsed'],
#  "'moprs": ["romp's", "prom's"],
#  'aensv': ['naves', 'evans', 'vanes'],
#  "'chmsu": ["much's", "chum's"],
#  'deopr': ['pored', 'roped', 'pedro'],
#  'aehors': ['hoarse', 'ashore'],
#  'einnost': ['tension', 'intones'],
#  "'emops": ["poem's", "mope's"],
#  'bekoor': ['brooke', 'booker'],
#  "'adrsy": ["yard's", "dray's"],
#  'aacelmr': ['caramel', 'carmela'],
#  'almpy': ['amply', 'palmy'],
#  "'abeilors": ["albireo's", "alberio's"],
#  'aelrst': ['slater', 'staler', 'alerts', 'salter', 'alters'],
#  'agikmns': ['makings', 'masking'],
#  'ehm': ['meh', 'hem'],
#  'bcehrstu': ['schubert', 'butchers'],
#  'abelstt': ['tablets', 'battles'],
#  'aagl': ['alga', 'gala'],
#  "'ahmss": ["sham's", "mash's"],
#  "'oorsst": ["torso's", "roost's"],
#  'aeinn': ['inane', 'annie'],
#  'eillvy': ['lively', 'evilly', 'vilely'],
#  'ehikt': ['kieth', 'keith'],
#  'acemprs': ['scamper', 'campers'],
#  "'defils": ["fidel's", "field's"],
#  'ademr': ['armed', 'dream'],
#  'aceehls': ['chelsea', 'leaches'],
#  'acelor': ['oracle', 'carole'],
#  "'aeinrrst": ["trainer's", "terrain's"],
#  'enostw': ['weston', 'townes'],
#  'aehnsy': ['haynes', 'hyenas'],
#  'aegr': ['gear', 'rage'],
#  'adeeln': ['leaned', 'leaden'],
#  "'aelsst": ["tesla's", "least's", "slate's", "steal's", "stael's"],
#  'aairt': ['atria', 'atari', 'tiara'],
#  'adefmr': ['framed', 'farmed'],
#  'eegkrs': ['greeks', 'kresge'],
#  'eimnrv': ['mervin', 'vermin'],
#  'eors': ['sore', 'rose', 'ores', 'eros', 'roes'],
#  "'ailrs": ["lira's", "lair's", "liar's", "rail's"],
#  'ablm': ['lamb', 'balm'],
#  'eeilnosss': ['noiseless', 'lionesses'],
#  "'cdeors": ["credo's", "decor's"],
#  "'eimnrsv": ["mervin's", "vermin's"],
#  'acins': ['incas', 'cains'],
#  'aelsw': ['weals', 'wales'],
#  "'aeprsy": ["payer's", "peary's"],
#  'ceefir': ['recife', 'fierce'],
#  "'gmsu": ["mug's", "gum's"],
#  'ellostu': ['outsell', 'sellout'],
#  'agilmn': ['laming', 'malign'],
#  'denrsu': ['nursed', 'sunder'],
#  "'horstw": ["worth's", "throw's"],
#  'eimrst': ['remits', 'merits', 'timers', 'mister', 'miters'],
#  "'adelsy": ["daley's", "delay's"],
#  'aefmrrs': ['framers', 'farmers'],
#  'cfio': ['coif', 'foci'],
#  'notw': ['wont', 'town'],
#  'amnorst': ['matrons', 'transom'],
#  'aeginrt': ['granite', 'ingrate', 'tearing', 'tangier'],
#  'aceilr': ['lacier', 'claire'],
#  'adeegr': ['geared', 'agreed'],
#  'eerw': ['weer', 'were', 'ewer'],
#  ...}

# %% [markdown]
# **Exercise 8:**
# Find the longest word with at least one anagram. Suggestion: use the `key` argument of `sort` or `sorted` ([see here](https://stackoverflow.com/questions/8966538/syntax-behind-sortedkey-lambda)).

# %%
max((v[0] for k,v in anagram_map.items() if len(v) > 1), key=len)
# Out:
# "impressiveness's"

# %% [markdown]
# **Exercise 9:**
# Find the largest list of words that are anagrams of each other.

# %%
max(((k, v) for k,v in anagram_map.items() if len(v) > 1), key=lambda a: len(a[1]))
# Out:
# ('aelst',
#  ['stael', 'stale', 'tales', 'slate', 'tesla', 'teals', 'steal', 'least'])

# %% [markdown]
# **Exercise 10:**
# Write a function that takes an integer `word_length` and finds the longest list of words with the given length that are anagrams of each other.

# %%
def longest_anagram_of_length(word_length: int, anagram_map: dict[str, list[str]])-> list[str]:
  return max(
      filter(lambda a: len(a[0]) == word_length,
             anagram_map.items()),
      key=lambda x:len(x[1])
  )

# %%
longest_anagram_of_length(4, anagram_map)
# Out:
# ('opst', ['pots', 'tops', 'spot', 'post', 'stop', 'opts'])

# %% [markdown]
# **Exercise 11:**
# At this point we have a data structure that contains lists of words that are anagrams, but we have not actually enumerated all pairs.
# Write a function that takes `anagram_map` and returns a list of all anagram pairs.
# How many are there?

# %%
def all_pairs(anagram_map):
    pairs = []
    for k, v in anagram_map.items():
      pairs.extend([(a,b) for a,b in product(v, v) if a != b])
    return pairs

# %%
all_pairs(anagram_map)
# Out:
# [('pediatrics', 'patricides'),
#  ('patricides', 'pediatrics'),
#  ("brief's", "fiber's"),
#  ("fiber's", "brief's"),
#  ('shrives', 'shivers'),
#  ('shivers', 'shrives'),
#  ('aligned', 'dealing'),
#  ('aligned', 'leading'),
#  ('dealing', 'aligned'),
#  ('dealing', 'leading'),
#  ('leading', 'aligned'),
#  ('leading', 'dealing'),
#  ("strop's", "sport's"),
#  ("sport's", "strop's"),
#  ("leona's", "oneal's"),
#  ("oneal's", "leona's"),
#  ('stimulate', 'mutilates'),
#  ('mutilates', 'stimulate'),
#  ('pains', 'spain'),
#  ('spain', 'pains'),
#  ('titters', 'tritest'),
#  ('tritest', 'titters'),
#  ('recitals', 'articles'),
#  ('articles', 'recitals'),
#  ("sorbet's", "osbert's"),
#  ("sorbet's", "strobe's"),
#  ("osbert's", "sorbet's"),
#  ("osbert's", "strobe's"),
#  ("strobe's", "sorbet's"),
#  ("strobe's", "osbert's"),
#  ("chain's", "icahn's"),
#  ("chain's", "china's"),
#  ("icahn's", "chain's"),
#  ("icahn's", "china's"),
#  ("china's", "chain's"),
#  ("china's", "icahn's"),
#  ("sleuth's", "hustle's"),
#  ("hustle's", "sleuth's"),
#  ('rubin', 'bruin'),
#  ('bruin', 'rubin'),
#  ("kilo's", "loki's"),
#  ("loki's", "kilo's"),
#  ('mats', 'tams'),
#  ('mats', 'mast'),
#  ('tams', 'mats'),
#  ('tams', 'mast'),
#  ('mast', 'mats'),
#  ('mast', 'tams'),
#  ('bore', 'boer'),
#  ('bore', 'ebro'),
#  ('bore', 'robe'),
#  ('boer', 'bore'),
#  ('boer', 'ebro'),
#  ('boer', 'robe'),
#  ('ebro', 'bore'),
#  ('ebro', 'boer'),
#  ('ebro', 'robe'),
#  ('robe', 'bore'),
#  ('robe', 'boer'),
#  ('robe', 'ebro'),
#  ('gums', 'smug'),
#  ('gums', 'mugs'),
#  ('smug', 'gums'),
#  ('smug', 'mugs'),
#  ('mugs', 'gums'),
#  ('mugs', 'smug'),
#  ('elastic', 'laciest'),
#  ('laciest', 'elastic'),
#  ('pended', 'depend'),
#  ('depend', 'pended'),
#  ("lime's", "emil's"),
#  ("lime's", "mile's"),
#  ("emil's", "lime's"),
#  ("emil's", "mile's"),
#  ("mile's", "lime's"),
#  ("mile's", "emil's"),
#  ('reparation', 'praetorian'),
#  ('praetorian', 'reparation'),
#  ('merited', 'mitered'),
#  ('merited', 'demerit'),
#  ('mitered', 'merited'),
#  ('mitered', 'demerit'),
#  ('demerit', 'merited'),
#  ('demerit', 'mitered'),
#  ('siberian', 'binaries'),
#  ('binaries', 'siberian'),
#  ("mantle's", "lament's"),
#  ("mantle's", "mantel's"),
#  ("lament's", "mantle's"),
#  ("lament's", "mantel's"),
#  ("mantel's", "mantle's"),
#  ("mantel's", "lament's"),
#  ('sheets', 'theses'),
#  ('theses', 'sheets'),
#  ('mined', 'denim'),
#  ('denim', 'mined'),
#  ("flesh's", "shelf's"),
#  ("shelf's", "flesh's"),
#  ('slivering', 'silvering'),
#  ('silvering', 'slivering'),
#  ("moral's", "molar's"),
#  ("molar's", "moral's"),
#  ('ranges', 'sanger'),
#  ('ranges', 'angers'),
#  ('sanger', 'ranges'),
#  ('sanger', 'angers'),
#  ('angers', 'ranges'),
#  ('angers', 'sanger'),
#  ('persian', 'paniers'),
#  ('paniers', 'persian'),
#  ('bored', 'robed'),
#  ('robed', 'bored'),
#  ('drains', 'nadirs'),
#  ('nadirs', 'drains'),
#  ("chasity's", "scythia's"),
#  ("scythia's", "chasity's"),
#  ('worth', 'wroth'),
#  ('worth', 'throw'),
#  ('wroth', 'worth'),
#  ('wroth', 'throw'),
#  ('throw', 'worth'),
#  ('throw', 'wroth'),
#  ("feat's", "fate's"),
#  ("feat's", "feta's"),
#  ("fate's", "feat's"),
#  ("fate's", "feta's"),
#  ("feta's", "feat's"),
#  ("feta's", "fate's"),
#  ("rosa's", "soar's"),
#  ("soar's", "rosa's"),
#  ('solo', 'oslo'),
#  ('oslo', 'solo'),
#  ('dawdled', 'waddled'),
#  ('waddled', 'dawdled'),
#  ('snit', 'tins'),
#  ('snit', 'nits'),
#  ('tins', 'snit'),
#  ('tins', 'nits'),
#  ('nits', 'snit'),
#  ('nits', 'tins'),
#  ("rant's", "tran's"),
#  ("tran's", "rant's"),
#  ("annam's", "manna's"),
#  ("manna's", "annam's"),
#  ('dormant', 'mordant'),
#  ('mordant', 'dormant'),
#  ('moral', 'molar'),
#  ('molar', 'moral'),
#  ('pots', 'tops'),
#  ('pots', 'spot'),
#  ('pots', 'post'),
#  ('pots', 'stop'),
#  ('pots', 'opts'),
#  ('tops', 'pots'),
#  ('tops', 'spot'),
#  ('tops', 'post'),
#  ('tops', 'stop'),
#  ('tops', 'opts'),
#  ('spot', 'pots'),
#  ('spot', 'tops'),
#  ('spot', 'post'),
#  ('spot', 'stop'),
#  ('spot', 'opts'),
#  ('post', 'pots'),
#  ('post', 'tops'),
#  ('post', 'spot'),
#  ('post', 'stop'),
#  ('post', 'opts'),
#  ('stop', 'pots'),
#  ('stop', 'tops'),
#  ('stop', 'spot'),
#  ('stop', 'post'),
#  ('stop', 'opts'),
#  ('opts', 'pots'),
#  ('opts', 'tops'),
#  ('opts', 'spot'),
#  ('opts', 'post'),
#  ('opts', 'stop'),
#  ('sprout', 'stupor'),
#  ('sprout', 'proust'),
#  ('stupor', 'sprout'),
#  ('stupor', 'proust'),
#  ('proust', 'sprout'),
#  ('proust', 'stupor'),
#  ("trio's", "riot's"),
#  ("trio's", "tiro's"),
#  ("riot's", "trio's"),
#  ("riot's", "tiro's"),
#  ("tiro's", "trio's"),
#  ("tiro's", "riot's"),
#  ('mason', 'moans'),
#  ('mason', 'osman'),
#  ('moans', 'mason'),
#  ('moans', 'osman'),
#  ('osman', 'mason'),
#  ('osman', 'moans'),
#  ("hectare's", "teacher's"),
#  ("hectare's", "cheater's"),
#  ("teacher's", "hectare's"),
#  ("teacher's", "cheater's"),
#  ("cheater's", "hectare's"),
#  ("cheater's", "teacher's"),
#  ('harms', 'marsh'),
#  ('marsh', 'harms'),
#  ('eats', 'sate'),
#  ('eats', 'seat'),
#  ('eats', 'east'),
#  ('eats', 'teas'),
#  ('sate', 'eats'),
#  ('sate', 'seat'),
#  ('sate', 'east'),
#  ('sate', 'teas'),
#  ('seat', 'eats'),
#  ('seat', 'sate'),
#  ('seat', 'east'),
#  ('seat', 'teas'),
#  ('east', 'eats'),
#  ('east', 'sate'),
#  ('east', 'seat'),
#  ('east', 'teas'),
#  ('teas', 'eats'),
#  ('teas', 'sate'),
#  ('teas', 'seat'),
#  ('teas', 'east'),
#  ('sub', 'bus'),
#  ('sub', 'ubs'),
#  ('bus', 'sub'),
#  ('bus', 'ubs'),
#  ('ubs', 'sub'),
#  ('ubs', 'bus'),
#  ('tureen', 'neuter'),
#  ('tureen', 'tenure'),
#  ('neuter', 'tureen'),
#  ('neuter', 'tenure'),
#  ('tenure', 'tureen'),
#  ('tenure', 'neuter'),
#  ('miter', 'merit'),
#  ('miter', 'remit'),
#  ('miter', 'timer'),
#  ('merit', 'miter'),
#  ('merit', 'remit'),
#  ('merit', 'timer'),
#  ('remit', 'miter'),
#  ('remit', 'merit'),
#  ('remit', 'timer'),
#  ('timer', 'miter'),
#  ('timer', 'merit'),
#  ('timer', 'remit'),
#  ('salted', 'deltas'),
#  ('salted', 'lasted'),
#  ('salted', 'slated'),
#  ('salted', 'staled'),
#  ('deltas', 'salted'),
#  ('deltas', 'lasted'),
#  ('deltas', 'slated'),
#  ('deltas', 'staled'),
#  ('lasted', 'salted'),
#  ('lasted', 'deltas'),
#  ('lasted', 'slated'),
#  ('lasted', 'staled'),
#  ('slated', 'salted'),
#  ('slated', 'deltas'),
#  ('slated', 'lasted'),
#  ('slated', 'staled'),
#  ('staled', 'salted'),
#  ('staled', 'deltas'),
#  ('staled', 'lasted'),
#  ('staled', 'slated'),
#  ("astor's", "roast's"),
#  ("astor's", "sarto's"),
#  ("roast's", "astor's"),
#  ("roast's", "sarto's"),
#  ("sarto's", "astor's"),
#  ("sarto's", "roast's"),
#  ('laxer', 'relax'),
#  ('relax', 'laxer'),
#  ('bean', 'bane'),
#  ('bane', 'bean'),
#  ('romero', 'roomer'),
#  ('roomer', 'romero'),
#  ("erewhon's", "nowhere's"),
#  ("nowhere's", "erewhon's"),
#  ('kids', 'skid'),
#  ('kids', 'disk'),
#  ('skid', 'kids'),
#  ('skid', 'disk'),
#  ('disk', 'kids'),
#  ('disk', 'skid'),
#  ('manured', 'maunder'),
#  ('manured', 'unarmed'),
#  ('maunder', 'manured'),
#  ('maunder', 'unarmed'),
#  ('unarmed', 'manured'),
#  ('unarmed', 'maunder'),
#  ('loot', 'tool'),
#  ('tool', 'loot'),
#  ('succor', 'occurs'),
#  ('succor', 'crocus'),
#  ('occurs', 'succor'),
#  ('occurs', 'crocus'),
#  ('crocus', 'succor'),
#  ('crocus', 'occurs'),
#  ('dapper', 'rapped'),
#  ('rapped', 'dapper'),
#  ("janine's", "jannie's"),
#  ("jannie's", "janine's"),
#  ('secures', 'rescues'),
#  ('rescues', 'secures'),
#  ("arno's", "nora's"),
#  ("arno's", "oran's"),
#  ("arno's", "roan's"),
#  ("arno's", "aron's"),
#  ("nora's", "arno's"),
#  ("nora's", "oran's"),
#  ("nora's", "roan's"),
#  ("nora's", "aron's"),
#  ("oran's", "arno's"),
#  ("oran's", "nora's"),
#  ("oran's", "roan's"),
#  ("oran's", "aron's"),
#  ("roan's", "arno's"),
#  ("roan's", "nora's"),
#  ("roan's", "oran's"),
#  ("roan's", "aron's"),
#  ("aron's", "arno's"),
#  ("aron's", "nora's"),
#  ("aron's", "oran's"),
#  ("aron's", "roan's"),
#  ('flowed', 'wolfed'),
#  ('flowed', 'fowled'),
#  ('wolfed', 'flowed'),
#  ('wolfed', 'fowled'),
#  ('fowled', 'flowed'),
#  ('fowled', 'wolfed'),
#  ('pertain', 'painter'),
#  ('pertain', 'repaint'),
#  ('painter', 'pertain'),
#  ('painter', 'repaint'),
#  ('repaint', 'pertain'),
#  ('repaint', 'painter'),
#  ('lycra', 'carly'),
#  ('carly', 'lycra'),
#  ("salem's", "selma's"),
#  ("selma's", "salem's"),
#  ('bulged', 'bugled'),
#  ('bugled', 'bulged'),
#  ('lube', 'blue'),
#  ('blue', 'lube'),
#  ('gina', 'gain'),
#  ('gina', 'agni'),
#  ('gain', 'gina'),
#  ('gain', 'agni'),
#  ('agni', 'gina'),
#  ('agni', 'gain'),
#  ('threads', 'hardest'),
#  ('threads', 'trashed'),
#  ('threads', 'dearths'),
#  ('threads', 'hatreds'),
#  ('hardest', 'threads'),
#  ('hardest', 'trashed'),
#  ('hardest', 'dearths'),
#  ('hardest', 'hatreds'),
#  ('trashed', 'threads'),
#  ('trashed', 'hardest'),
#  ('trashed', 'dearths'),
#  ('trashed', 'hatreds'),
#  ('dearths', 'threads'),
#  ('dearths', 'hardest'),
#  ('dearths', 'trashed'),
#  ('dearths', 'hatreds'),
#  ('hatreds', 'threads'),
#  ('hatreds', 'hardest'),
#  ('hatreds', 'trashed'),
#  ('hatreds', 'dearths'),
#  ('elvis', 'evils'),
#  ('elvis', 'veils'),
#  ('elvis', 'lives'),
#  ('evils', 'elvis'),
#  ('evils', 'veils'),
#  ('evils', 'lives'),
#  ('veils', 'elvis'),
#  ('veils', 'evils'),
#  ('veils', 'lives'),
#  ('lives', 'elvis'),
#  ('lives', 'evils'),
#  ('lives', 'veils'),
#  ('ismael', 'melisa'),
#  ('ismael', 'emails'),
#  ('melisa', 'ismael'),
#  ('melisa', 'emails'),
#  ('emails', 'ismael'),
#  ('emails', 'melisa'),
#  ('stares', 'asters'),
#  ('stares', 'assert'),
#  ('stares', 'tasers'),
#  ('asters', 'stares'),
#  ('asters', 'assert'),
#  ('asters', 'tasers'),
#  ('assert', 'stares'),
#  ('assert', 'asters'),
#  ('assert', 'tasers'),
#  ('tasers', 'stares'),
#  ('tasers', 'asters'),
#  ('tasers', 'assert'),
#  ('umlaut', 'mutual'),
#  ('mutual', 'umlaut'),
#  ('calks', 'lacks'),
#  ('calks', 'slack'),
#  ('lacks', 'calks'),
#  ('lacks', 'slack'),
#  ('slack', 'calks'),
#  ('slack', 'lacks'),
#  ('tilled', 'lilted'),
#  ('lilted', 'tilled'),
#  ("vial's", "vila's"),
#  ("vila's", "vial's"),
#  ('taverns', 'servant'),
#  ('servant', 'taverns'),
#  ('rebirth', 'birther'),
#  ('birther', 'rebirth'),
#  ('onsets', 'stones'),
#  ('stones', 'onsets'),
#  ("sirup's", "prius's"),
#  ("prius's", "sirup's"),
#  ('debuts', 'busted'),
#  ('busted', 'debuts'),
#  ('islam', 'mails'),
#  ('mails', 'islam'),
#  ('lestrade', 'treadles'),
#  ('treadles', 'lestrade'),
#  ("harte's", "heart's"),
#  ("harte's", "earth's"),
#  ("harte's", "hater's"),
#  ("heart's", "harte's"),
#  ("heart's", "earth's"),
#  ("heart's", "hater's"),
#  ("earth's", "harte's"),
#  ("earth's", "heart's"),
#  ("earth's", "hater's"),
#  ("hater's", "harte's"),
#  ("hater's", "heart's"),
#  ("hater's", "earth's"),
#  ('blushes', 'bushels'),
#  ('bushels', 'blushes'),
#  ('lancaster', 'ancestral'),
#  ('ancestral', 'lancaster'),
#  ('greens', 'genres'),
#  ('genres', 'greens'),
#  ("point's", "pinto's"),
#  ("point's", "piton's"),
#  ("pinto's", "point's"),
#  ("pinto's", "piton's"),
#  ("piton's", "point's"),
#  ("piton's", "pinto's"),
#  ('rebuts', 'buster'),
#  ('rebuts', 'tubers'),
#  ('rebuts', 'brutes'),
#  ('buster', 'rebuts'),
#  ('buster', 'tubers'),
#  ('buster', 'brutes'),
#  ('tubers', 'rebuts'),
#  ('tubers', 'buster'),
#  ('tubers', 'brutes'),
#  ('brutes', 'rebuts'),
#  ('brutes', 'buster'),
#  ('brutes', 'tubers'),
#  ('slyest', 'styles'),
#  ('styles', 'slyest'),
#  ('mangers', 'germans'),
#  ('germans', 'mangers'),
#  ('rebind', 'binder'),
#  ('rebind', 'inbred'),
#  ('binder', 'rebind'),
#  ('binder', 'inbred'),
#  ('inbred', 'rebind'),
#  ('inbred', 'binder'),
#  ('diego', 'dogie'),
#  ('dogie', 'diego'),
#  ('geldings', 'sledging'),
#  ('sledging', 'geldings'),
#  ('rockets', 'restock'),
#  ('restock', 'rockets'),
#  ('distincter', 'interdicts'),
#  ('interdicts', 'distincter'),
#  ('pets', 'step'),
#  ('pets', 'pest'),
#  ('step', 'pets'),
#  ('step', 'pest'),
#  ('pest', 'pets'),
#  ('pest', 'step'),
#  ('si', 'is'),
#  ('is', 'si'),
#  ('weans', 'wanes'),
#  ('wanes', 'weans'),
#  ("tory's", "troy's"),
#  ("tory's", "tyro's"),
#  ("troy's", "tory's"),
#  ("troy's", "tyro's"),
#  ("tyro's", "tory's"),
#  ("tyro's", "troy's"),
#  ('erections', 'secretion'),
#  ('secretion', 'erections'),
#  ("bosun's", "bonus's"),
#  ("bosun's", "bo'suns"),
#  ("bonus's", "bosun's"),
#  ("bonus's", "bo'suns"),
#  ("bo'suns", "bosun's"),
#  ("bo'suns", "bonus's"),
#  ('genies', 'seeing'),
#  ('seeing', 'genies'),
#  ("carly's", "lycra's"),
#  ("lycra's", "carly's"),
#  ('megatons', 'montages'),
#  ('megatons', 'magnetos'),
#  ('montages', 'megatons'),
#  ('montages', 'magnetos'),
#  ('magnetos', 'megatons'),
#  ('magnetos', 'montages'),
#  ('matins', 'mantis'),
#  ('mantis', 'matins'),
#  ("tiber's", "tribe's"),
#  ("tribe's", "tiber's"),
#  ('thor', 'roth'),
#  ('roth', 'thor'),
#  ('frosted', 'defrost'),
#  ('defrost', 'frosted'),
#  ('density', 'destiny'),
#  ('destiny', 'density'),
#  ('ponder', 'pernod'),
#  ('pernod', 'ponder'),
#  ('mantelpiece', 'mantlepiece'),
#  ('mantlepiece', 'mantelpiece'),
#  ('lorre', 'errol'),
#  ('errol', 'lorre'),
#  ('stan', 'ants'),
#  ('stan', 'tans'),
#  ('ants', 'stan'),
#  ('ants', 'tans'),
#  ('tans', 'stan'),
#  ('tans', 'ants'),
#  ('poisoned', 'poseidon'),
#  ('poseidon', 'poisoned'),
#  ('alms', 'slam'),
#  ('alms', 'lams'),
#  ('slam', 'alms'),
#  ('slam', 'lams'),
#  ('lams', 'alms'),
#  ('lams', 'slam'),
#  ('wendi', 'edwin'),
#  ('wendi', 'wined'),
#  ('wendi', 'widen'),
#  ('edwin', 'wendi'),
#  ('edwin', 'wined'),
#  ('edwin', 'widen'),
#  ('wined', 'wendi'),
#  ('wined', 'edwin'),
#  ('wined', 'widen'),
#  ('widen', 'wendi'),
#  ('widen', 'edwin'),
#  ('widen', 'wined'),
#  ('rasping', 'parsing'),
#  ('rasping', 'sparing'),
#  ('rasping', 'parings'),
#  ('parsing', 'rasping'),
#  ('parsing', 'sparing'),
#  ('parsing', 'parings'),
#  ('sparing', 'rasping'),
#  ('sparing', 'parsing'),
#  ('sparing', 'parings'),
#  ('parings', 'rasping'),
#  ('parings', 'parsing'),
#  ('parings', 'sparing'),
#  ('trace', 'cater'),
#  ('trace', 'react'),
#  ('trace', 'crate'),
#  ('trace', 'recta'),
#  ('trace', 'caret'),
#  ('cater', 'trace'),
#  ('cater', 'react'),
#  ('cater', 'crate'),
#  ('cater', 'recta'),
#  ('cater', 'caret'),
#  ('react', 'trace'),
#  ('react', 'cater'),
#  ('react', 'crate'),
#  ('react', 'recta'),
#  ('react', 'caret'),
#  ('crate', 'trace'),
#  ('crate', 'cater'),
#  ('crate', 'react'),
#  ('crate', 'recta'),
#  ('crate', 'caret'),
#  ('recta', 'trace'),
#  ('recta', 'cater'),
#  ('recta', 'react'),
#  ('recta', 'crate'),
#  ('recta', 'caret'),
#  ('caret', 'trace'),
#  ('caret', 'cater'),
#  ('caret', 'react'),
#  ('caret', 'crate'),
#  ('caret', 'recta'),
#  ('apropos', 'sapporo'),
#  ('sapporo', 'apropos'),
#  ('gem', 'meg'),
#  ('meg', 'gem'),
#  ('break', 'baker'),
#  ('break', 'brake'),
#  ('baker', 'break'),
#  ('baker', 'brake'),
#  ('brake', 'break'),
#  ('brake', 'baker'),
#  ('deranged', 'gardened'),
#  ('gardened', 'deranged'),
#  ('romans', 'manors'),
#  ('romans', 'ransom'),
#  ('manors', 'romans'),
#  ('manors', 'ransom'),
#  ('ransom', 'romans'),
#  ('ransom', 'manors'),
#  ("perfect's", "prefect's"),
#  ("prefect's", "perfect's"),
#  ('prattle', 'platter'),
#  ('platter', 'prattle'),
#  ("cold's", "clod's"),
#  ("clod's", "cold's"),
#  ('demurred', 'murdered'),
#  ('murdered', 'demurred'),
#  ('thickens', 'kitchens'),
#  ('kitchens', 'thickens'),
#  ('baal', 'alba'),
#  ('alba', 'baal'),
#  ('hams', 'sham'),
#  ('hams', 'mash'),
#  ('sham', 'hams'),
#  ('sham', 'mash'),
#  ('mash', 'hams'),
#  ('mash', 'sham'),
#  ('salver', 'ravels'),
#  ('salver', 'slaver'),
#  ('ravels', 'salver'),
#  ('ravels', 'slaver'),
#  ('slaver', 'salver'),
#  ('slaver', 'ravels'),
#  ('piebald', 'bipedal'),
#  ('bipedal', 'piebald'),
#  ("ti's", "it's"),
#  ("it's", "ti's"),
#  ("gnat's", "tang's"),
#  ("tang's", "gnat's"),
#  ("postage's", "gestapo's"),
#  ("gestapo's", "postage's"),
#  ('echos', 'chose'),
#  ('chose', 'echos'),
#  ("brag's", "grab's"),
#  ("brag's", "garb's"),
#  ("grab's", "brag's"),
#  ("grab's", "garb's"),
#  ("garb's", "brag's"),
#  ("garb's", "grab's"),
#  ('breaks', 'brakes'),
#  ('breaks', 'bakers'),
#  ('brakes', 'breaks'),
#  ('brakes', 'bakers'),
#  ('bakers', 'breaks'),
#  ('bakers', 'brakes'),
#  ('heirs', 'sheri'),
#  ('heirs', 'shire'),
#  ('heirs', 'hires'),
#  ('sheri', 'heirs'),
#  ('sheri', 'shire'),
#  ('sheri', 'hires'),
#  ('shire', 'heirs'),
#  ('shire', 'sheri'),
#  ('shire', 'hires'),
#  ('hires', 'heirs'),
#  ('hires', 'sheri'),
#  ('hires', 'shire'),
#  ('nevis', 'veins'),
#  ('nevis', 'vines'),
#  ('veins', 'nevis'),
#  ('veins', 'vines'),
#  ('vines', 'nevis'),
#  ('vines', 'veins'),
#  ("mimosa's", "maoism's"),
#  ("maoism's", "mimosa's"),
#  ('aron', 'nora'),
#  ('aron', 'roan'),
#  ('aron', 'oran'),
#  ('aron', 'arno'),
#  ('nora', 'aron'),
#  ('nora', 'roan'),
#  ('nora', 'oran'),
#  ('nora', 'arno'),
#  ('roan', 'aron'),
#  ('roan', 'nora'),
#  ('roan', 'oran'),
#  ('roan', 'arno'),
#  ('oran', 'aron'),
#  ('oran', 'nora'),
#  ('oran', 'roan'),
#  ('oran', 'arno'),
#  ('arno', 'aron'),
#  ('arno', 'nora'),
#  ('arno', 'roan'),
#  ('arno', 'oran'),
#  ("turbine's", "tribune's"),
#  ("tribune's", "turbine's"),
#  ('sets', 'tess'),
#  ('tess', 'sets'),
#  ('naivest', 'vainest'),
#  ('naivest', 'natives'),
#  ('vainest', 'naivest'),
#  ('vainest', 'natives'),
#  ('natives', 'naivest'),
#  ('natives', 'vainest'),
#  ('warding', 'drawing'),
#  ('drawing', 'warding'),
#  ('note', 'tone'),
#  ('note', 'eton'),
#  ('tone', 'note'),
#  ('tone', 'eton'),
#  ('eton', 'note'),
#  ('eton', 'tone'),
#  ('fared', 'freda'),
#  ('freda', 'fared'),
#  ("rosie's", "osier's"),
#  ("osier's", "rosie's"),
#  ('pool', 'loop'),
#  ('pool', 'polo'),
#  ('loop', 'pool'),
#  ('loop', 'polo'),
#  ('polo', 'pool'),
#  ('polo', 'loop'),
#  ("iso's", "ios's"),
#  ("ios's", "iso's"),
#  ('grudging', 'drugging'),
#  ('drugging', 'grudging'),
#  ('laban', 'banal'),
#  ('banal', 'laban'),
#  ("rout's", "tour's"),
#  ("tour's", "rout's"),
#  ('lingo', 'login'),
#  ('login', 'lingo'),
#  ('adorns', 'sondra'),
#  ('sondra', 'adorns'),
#  ('oared', 'adore'),
#  ('adore', 'oared'),
#  ('urns', 'runs'),
#  ('runs', 'urns'),
#  ('elects', 'select'),
#  ('select', 'elects'),
#  ('pinochet', 'phonetic'),
#  ('phonetic', 'pinochet'),
#  ("susana's", "nassau's"),
#  ("nassau's", "susana's"),
#  ("jeannie's", "jeanine's"),
#  ("jeanine's", "jeannie's"),
#  ('amphitheatres', 'amphitheaters'),
#  ('amphitheaters', 'amphitheatres'),
#  ('griffin', 'riffing'),
#  ('riffing', 'griffin'),
#  ('manilas', 'animals'),
#  ('manilas', 'malians'),
#  ('animals', 'manilas'),
#  ('animals', 'malians'),
#  ('malians', 'manilas'),
#  ('malians', 'animals'),
#  ("elmer's", "merle's"),
#  ("merle's", "elmer's"),
#  ('predators', 'teardrops'),
#  ('teardrops', 'predators'),
#  ('domes', 'modes'),
#  ('domes', 'demos'),
#  ('modes', 'domes'),
#  ('modes', 'demos'),
#  ('demos', 'domes'),
#  ('demos', 'modes'),
#  ('looters', 'retools'),
#  ('retools', 'looters'),
#  ("hunk's", "kuhn's"),
#  ("kuhn's", "hunk's"),
#  ('serest', 'steers'),
#  ('serest', 'esters'),
#  ('serest', 'resets'),
#  ('steers', 'serest'),
#  ('steers', 'esters'),
#  ('steers', 'resets'),
#  ('esters', 'serest'),
#  ('esters', 'steers'),
#  ('esters', 'resets'),
#  ('resets', 'serest'),
#  ('resets', 'steers'),
#  ('resets', 'esters'),
#  ('lamar', 'alarm'),
#  ('lamar', 'marla'),
#  ('alarm', 'lamar'),
#  ('alarm', 'marla'),
#  ('marla', 'lamar'),
#  ('marla', 'alarm'),
#  ('ignore', 'region'),
#  ('region', 'ignore'),
#  ('nominates', 'minnesota'),
#  ('minnesota', 'nominates'),
#  ('slat', 'lats'),
#  ('slat', 'last'),
#  ('slat', 'salt'),
#  ('lats', 'slat'),
#  ('lats', 'last'),
#  ('lats', 'salt'),
#  ('last', 'slat'),
#  ('last', 'lats'),
#  ('last', 'salt'),
#  ('salt', 'slat'),
#  ('salt', 'lats'),
#  ('salt', 'last'),
#  ("arson's", "sonar's"),
#  ("sonar's", "arson's"),
#  ('crumpets', 'spectrum'),
#  ('spectrum', 'crumpets'),
#  ('insoles', 'lesions'),
#  ('insoles', 'lioness'),
#  ('lesions', 'insoles'),
#  ('lesions', 'lioness'),
#  ('lioness', 'insoles'),
#  ('lioness', 'lesions'),
#  ('impart', 'armpit'),
#  ('armpit', 'impart'),
#  ('askew', 'wesak'),
#  ('askew', 'wakes'),
#  ('wesak', 'askew'),
#  ('wesak', 'wakes'),
#  ('wakes', 'askew'),
#  ('wakes', 'wesak'),
#  ('please', 'elapse'),
#  ('please', 'asleep'),
#  ('elapse', 'please'),
#  ('elapse', 'asleep'),
#  ('asleep', 'please'),
#  ('asleep', 'elapse'),
#  ('bacterial', 'calibrate'),
#  ('calibrate', 'bacterial'),
#  ('assess', 'sasses'),
#  ('sasses', 'assess'),
#  ('subtler', 'butlers'),
#  ('subtler', 'bluster'),
#  ('butlers', 'subtler'),
#  ('butlers', 'bluster'),
#  ('bluster', 'subtler'),
#  ('bluster', 'butlers'),
#  ('tilts', 'stilt'),
#  ('stilt', 'tilts'),
#  ("tuber's", "brute's"),
#  ("brute's", "tuber's"),
#  ('skype', 'pesky'),
#  ('pesky', 'skype'),
#  ('tender', 'rented'),
#  ('rented', 'tender'),
#  ('rages', 'gears'),
#  ('rages', 'sager'),
#  ('gears', 'rages'),
#  ('gears', 'sager'),
#  ('sager', 'rages'),
#  ('sager', 'gears'),
#  ('shades', 'dashes'),
#  ('dashes', 'shades'),
#  ('cohen', 'enoch'),
#  ('enoch', 'cohen'),
#  ("sakai's", "kasai's"),
#  ("kasai's", "sakai's"),
#  ('seedier', 'desiree'),
#  ('desiree', 'seedier'),
#  ('theatre', 'theater'),
#  ('theater', 'theatre'),
#  ("wrap's", "warp's"),
#  ("warp's", "wrap's"),
#  ('havens', 'shaven'),
#  ('shaven', 'havens'),
#  ('brunt', 'burnt'),
#  ('burnt', 'brunt'),
#  ('dances', 'ascend'),
#  ('ascend', 'dances'),
#  ("bos'ns", "snob's"),
#  ("snob's", "bos'ns"),
#  ('hankers', 'harkens'),
#  ('harkens', 'hankers'),
#  ("car's", "arc's"),
#  ("car's", "rca's"),
#  ("arc's", "car's"),
#  ("arc's", "rca's"),
#  ("rca's", "car's"),
#  ("rca's", "arc's"),
#  ('megan', 'mange'),
#  ('megan', 'amgen'),
#  ('mange', 'megan'),
#  ('mange', 'amgen'),
#  ('amgen', 'megan'),
#  ('amgen', 'mange'),
#  ('gaunt', 'gatun'),
#  ('gatun', 'gaunt'),
#  ('gander', 'garden'),
#  ('gander', 'ranged'),
#  ('gander', 'danger'),
#  ('garden', 'gander'),
#  ('garden', 'ranged'),
#  ('garden', 'danger'),
#  ('ranged', 'gander'),
#  ('ranged', 'garden'),
#  ('ranged', 'danger'),
#  ('danger', 'gander'),
#  ('danger', 'garden'),
#  ('danger', 'ranged'),
#  ('nearness', 'ensnares'),
#  ('ensnares', 'nearness'),
#  ('caterer', 'terrace'),
#  ('caterer', 'retrace'),
#  ('terrace', 'caterer'),
#  ('terrace', 'retrace'),
#  ('retrace', 'caterer'),
#  ('retrace', 'terrace'),
#  ('glass', 'slags'),
#  ('slags', 'glass'),
#  ('condors', 'cordons'),
#  ('cordons', 'condors'),
#  ("norad's", "drano's"),
#  ("norad's", "ronda's"),
#  ("norad's", "radon's"),
#  ("drano's", "norad's"),
#  ("drano's", "ronda's"),
#  ("drano's", "radon's"),
#  ("ronda's", "norad's"),
#  ("ronda's", "drano's"),
#  ("ronda's", "radon's"),
#  ("radon's", "norad's"),
#  ("radon's", "drano's"),
#  ("radon's", "ronda's"),
#  ('starved', 'adverts'),
#  ('adverts', 'starved'),
#  ('sunspot', 'unstops'),
#  ('unstops', 'sunspot'),
#  ('groans', 'sarong'),
#  ('groans', 'organs'),
#  ('groans', 'sargon'),
#  ('sarong', 'groans'),
#  ('sarong', 'organs'),
#  ('sarong', 'sargon'),
#  ('organs', 'groans'),
#  ('organs', 'sarong'),
#  ('organs', 'sargon'),
#  ('sargon', 'groans'),
#  ('sargon', 'sarong'),
#  ('sargon', 'organs'),
#  ('publisher', 'republish'),
#  ('republish', 'publisher'),
#  ('sony', 'nosy'),
#  ('nosy', 'sony'),
#  ('encoder', 'encored'),
#  ('encored', 'encoder'),
#  ('spend', 'pends'),
#  ('pends', 'spend'),
#  ('coveting', 'vietcong'),
#  ('vietcong', 'coveting'),
#  ('kilning', 'inkling'),
#  ('kilning', 'linking'),
#  ('inkling', 'kilning'),
#  ('inkling', 'linking'),
#  ('linking', 'kilning'),
#  ('linking', 'inkling'),
#  ('warms', 'swarm'),
#  ('swarm', 'warms'),
#  ('reno', 'nero'),
#  ('nero', 'reno'),
#  ("sectional's", "coastline's"),
#  ("coastline's", "sectional's"),
#  ('not', 'ton'),
#  ('ton', 'not'),
#  ('highest', 'eighths'),
#  ('highest', 'heights'),
#  ('eighths', 'highest'),
#  ('eighths', 'heights'),
#  ('heights', 'highest'),
#  ('heights', 'eighths'),
#  ("shauna's", "nashua's"),
#  ("nashua's", "shauna's"),
#  ('edge', 'geed'),
#  ('geed', 'edge'),
#  ("tun's", "nut's"),
#  ("nut's", "tun's"),
#  ("virgo's", "vigor's"),
#  ("vigor's", "virgo's"),
#  ('fleeing', 'feeling'),
#  ('feeling', 'fleeing'),
#  ("workhouse's", "housework's"),
#  ("housework's", "workhouse's"),
#  ('tories', 'sortie'),
#  ('sortie', 'tories'),
#  ('marcel', 'calmer'),
#  ('calmer', 'marcel'),
#  ('loci', 'coil'),
#  ('loci', 'clio'),
#  ...]

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
